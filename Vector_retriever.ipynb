# %% [markdown]
# ### Vector stores and retrievers
# These abstractions are designed to support retrieval of data-- from (vector) databases and other sources-- for integration with LLM workflows. They are important for applications that fetch data to be reasoned over as part of model inference, as in the case of retrieval-augmented generation.
#
# We will cover
# - Documents
# - Vector stores
# - Retrievers

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")
os.environ["GROQ_API_KEY"]= os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Documents
# LangChain implements a Document abstraction, which is intended to represent a unit of text and associated metadata. It has two attributes:
#
# - page_content: a string representing the content;
# - metadata: a dict containing arbitrary metadata.
# The metadata attribute can capture information about the source of the document, its relationship to other documents, and other information. Note that an individual Document object often represents a chunk of a larger document.
#
# Let's generate some sample documents:

# %%
from langchain_core.documents import Document

documents = [
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent pets that often enjoy their own space.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Goldfish are popular pets for beginners, requiring relatively simple care.",
        metadata={"source": "fish-pets-doc"},
    ),
    Document(
        page_content="Parrots are intelligent birds capable of mimicking human speech.",
        metadata={"source": "bird-pets-doc"},
    ),
    Document(
        page_content="Rabbits are social animals that need plenty of space to hop around.",
        metadata={"source": "mammal-pets-doc"},
    ),
]

# %%
documents
# Out:
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(metadata={'source': 'fish-pets-doc'}, page_content='Goldfish are popular pets for beginners, requiring relatively simple care.'),
#  Document(metadata={'source': 'bird-pets-doc'}, page_content='Parrots are intelligent birds capable of mimicking human speech.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Rabbits are social animals that need plenty of space to hop around.')]

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(groq_api_key=os.environ["GROQ_API_KEY"],model="Llama3-8b-8192")
llm
# Out:
# ChatGroq(profile={}, client=<groq.resources.chat.completions.Completions object at 0x0000020B2D39A680>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000020B2D4357B0>, model_name='Llama3-8b-8192', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 from langchain_huggingface import HuggingFaceEmbeddings
# ----> 2 embeddings=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\langchain_huggingface\embeddings\huggingface.py:68, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      66 super().__init__(**kwargs)
#      67 try:
# ---> 68     import sentence_transformers  # type: ignore[import]
#      69 except ImportError as exc:
#      70     msg = (
#      71         "Could not import sentence_transformers python package. "
#      72         "Please install it with `pip install sentence-transformers`."
#      73     )
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:35
#      33 from sentence_transformers import __version__
#      34 from sentence_transformers.backend import load_onnx_model, load_openvino_model
# ---> 35 from sentence_transformers.cross_encoder.fit_mixin import FitMixin
#      36 from sentence_transformers.cross_encoder.model_card import CrossEncoderModelCardData, generate_model_card
#      37 from sentence_transformers.cross_encoder.util import (
#      38     cross_encoder_init_args_decorator,
#      39     cross_encoder_predict_rank_args_decorator,
#      40 )
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\sentence_transformers\cross_encoder\fit_mixin.py:20
#      17 from transformers.tokenization_utils_base import BatchEncoding
#      19 from sentence_transformers.cross_encoder.training_args import CrossEncoderTrainingArguments
# ---> 20 from sentence_transformers.datasets.NoDuplicatesDataLoader import NoDuplicatesDataLoader
#      21 from sentence_transformers.datasets.SentenceLabelDataset import SentenceLabelDataset
#      22 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\sentence_transformers\datasets\__init__.py:13
#      11 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#      12 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 13 from .ParallelSentencesDataset import ParallelSentencesDataset
#      14 from .SentenceLabelDataset import SentenceLabelDataset
#      15 from .SentencesDataset import SentencesDataset
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\sentence_transformers\datasets\ParallelSentencesDataset.py:19
#      15 import random
#      17 from torch.utils.data import Dataset
# ---> 19 from sentence_transformers import SentenceTransformer
#      20 from sentence_transformers.readers import InputExample
#      22 logger = logging.getLogger(__name__)
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\sentence_transformers\SentenceTransformer.py:45
#      43 from .fit_mixin import FitMixin
#      44 from .models import Pooling, Transformer
# ---> 45 from .peft_mixin import PeftAdapterMixin
#      46 from .quantization import quantize_embeddings
#      47 from .util import (
#      48     batch_to_device,
#      49     get_device_name,
#    (...)
#      55     truncate_embeddings,
#      56 )
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\sentence_transformers\peft_mixin.py:5
#       1 from __future__ import annotations
#       3 from functools import wraps
# ----> 5 from transformers.integrations.peft import PeftAdapterMixin as PeftAdapterMixinTransformers
#       8 def peft_wrapper(func):
#       9     """Wrapper to call the method on the auto_model with a check for PEFT compatibility."""
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\transformers\integrations\peft.py:22
#      19 from dataclasses import replace
#      20 from typing import TYPE_CHECKING, Any, Literal, Optional
# ---> 22 from ..conversion_mapping import (
#      23     _MODEL_TO_CONVERSION_PATTERN,
#      24     get_checkpoint_conversion_mapping,
#      25     get_model_conversion_mapping,
#      26 )
#      27 from ..core_model_loading import (
#      28     Concatenate,
#      29     ConversionOps,
#    (...)
#      33     WeightRenaming,
#      34 )
#      35 from ..utils import (
#      36     CONFIG_NAME,
#      37     cached_file,
#    (...)
#      44     logging,
#      45 )
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\transformers\conversion_mapping.py:20
#      17 from copy import deepcopy
#      18 from typing import TYPE_CHECKING
# ---> 20 from .core_model_loading import (
#      21     Chunk,
#      22     Concatenate,
#      23     ErnieFuseAndSplitTextVisionExperts,
#      24     Force16BytesAlignment,
#      25     MergeModulelist,
#      26     Transpose,
#      27     WeightConverter,
#      28     WeightRenaming,
#      29 )
#      30 from .utils import is_torch_available
#      33 if is_torch_available():
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\transformers\core_model_loading.py:33
#      29 from typing import TYPE_CHECKING, Any
#      31 import torch
# ---> 33 from .integrations.accelerate import get_device, offload_weight
#      34 from .integrations.tensor_parallel import ALL_PARALLEL_STYLES
#      35 from .utils import is_env_variable_true, is_torch_greater_or_equal, logging
#
# File c:\code\learnings\gen-ai\chatbot with conversation history\venv\lib\site-packages\transformers\integrations\accelerate.py:155
#     150             all_module_sizes[name] += size
#     152     return all_module_sizes, leaves_module_sizes
# --> 155 def compute_module_total_buffer_size(model: nn.Module, hf_quantizer: "HfQuantizer | None" = None):
#     156     """
#     157     Compute the total size of buffers in each submodule of a given model.
#     158     """
#     159     module_sizes, _ = compute_module_sizes(model, hf_quantizer, buffers_only=True)
#
# NameError: name 'nn' is not defined
